# %%
import numpy as np
import pandas as pd
from time import time
from sklearn.metrics import f1_score
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.append('../')

from ract import Action, RecourseTreeClassifier
from datasets import Dataset

# %%
DATASETS = ['c', 'f', 'b', 'p']

COST_TYPE = 'MPS'
COST_BUDGETS = [0.1, 0.2, 0.4, 0.5]

MAX_DEPTH = 64
ALPHAS = {
    'f': [0.0, 0.025, 0.05, 0.075, 0.1], 
    'c': [0.0, 0.025, 0.05, 0.075, 0.1], 
    'p': [0.0, 0.025, 0.05, 0.075, 0.1], 
    'b': [0.0, 0.025, 0.05, 0.075, 0.1], 
}
DELTAS = [0.2, 0.25, 0.3, 0.35, 0.4]

KEYS_GROUPBY = [
    'Budget',
    'Method',
    'Alpha',
    'Delta', 
]
KEYS_MODEL = [
    'Accuracy',
    'F1',
    'Time [s]',
]
KEYS_ACTION = [
    'Cost',
    'Validity',
    'Budget-Validity',
    'Valid-Cost',
    'Recourse', 
    'Sparsity', 
    'Plausibility',
]

# %%
def run_holdout_tree(dataset='g', causal=False, n_split=30):
    np.random.seed(0)
    
    D = Dataset(dataset=dataset)
    X, y = D.get_dataset()
    params = D.params
    
    results = {
        'Fold': [],
        'Method': [],
        'Alpha': [],
        'Delta': [], 
        'Budget': [],
        'Accuracy': [],
        'F1': [],
        'Time [s]': [],
        'Cost': [],
        'Validity': [],
        'Budget-Validity': [],
        'Valid-Cost': [], 
        'Recourse': [], 
        'Sparsity': [],
        'Plausibility': [],
    }
    importance = []
    
    for k in range(n_split):
        k = k + 1
        X_tr, X_ts, y_tr, y_ts = train_test_split(X, y)

        iforest = IsolationForest(n_estimators=100).fit(X_tr)
        action = Action(X_tr, y_target=0, cost_type=COST_TYPE, causal=causal, **params)
        
        print('- k = {}'.format(k))
        for cost_budget in COST_BUDGETS:
            action.cost_budget = cost_budget

            print('\t- budget: {}'.format(cost_budget))
            for alpha in ALPHAS[dataset]:
                if alpha == 0.0:
                    clf = RecourseTreeClassifier(action, max_depth=MAX_DEPTH)
                    clf.action.alpha = alpha

                    start = time()
                    clf = clf.fit(X_tr, y_tr)
                    runtime = time() - start
                    X_target = X_ts[clf.predict(X_ts) != action.y_target]
                    result = clf.explain_action(X_target)
        
                    results['Fold'].append(k); results['Method'].append('Baseline'); 
                    results['Alpha'].append(alpha); results['Budget'].append(cost_budget); results['Delta'].append(1.0); 
                    results['Accuracy'].append(clf.score(X_ts, y_ts)); results['F1'].append(f1_score(y_ts, clf.predict(X_ts))); results['Time [s]'].append(runtime); 
                    results['Cost'].append(result['cost'].mean()); results['Validity'].append(result['validity'].mean()); 
                    results['Budget-Validity'].append(result['cost-validity'].mean()); results['Valid-Cost'].append(result['valid-cost'].mean()); 
                    results['Recourse'].append(1 - (~result['cost-validity']).sum() / X_ts.shape[0]); 
                    results['Sparsity'].append(result['valid-sparsity'].mean()); 
                    results['Plausibility'].append(-1 * iforest.score_samples(result['counterfactual']).mean() if X_target.shape[0]!=0 else 0.0); 
                    print('\t\t\t- Method: {} (alp.: {}) | Acc.: {:.4} | Val.: {:.4} | Rec.: {:.4}'.format(results['Method'][-1], alpha, results['Accuracy'][-1], results['Budget-Validity'][-1], results['Recourse'][-1]))
                    importance.append(clf.feature_importances_)


                    clf = RecourseTreeClassifier(action, max_depth=MAX_DEPTH, feature_masking=True)
                    clf.action.alpha = alpha

                    start = time()
                    clf = clf.fit(X_tr, y_tr)
                    runtime = time() - start
                    X_target = X_ts[clf.predict(X_ts) != action.y_target]
                    result = clf.explain_action(X_target)

                    results['Fold'].append(k); results['Method'].append('Baseline (OAF)'); 
                    results['Alpha'].append(alpha); results['Budget'].append(cost_budget); results['Delta'].append(1.0); 
                    results['Accuracy'].append(clf.score(X_ts, y_ts)); results['F1'].append(f1_score(y_ts, clf.predict(X_ts))); results['Time [s]'].append(runtime); 
                    results['Cost'].append(result['cost'].mean()); results['Validity'].append(result['validity'].mean()); 
                    results['Budget-Validity'].append(result['cost-validity'].mean()); results['Valid-Cost'].append(result['valid-cost'].mean()); 
                    results['Recourse'].append(1 - (~result['cost-validity']).sum() / X_ts.shape[0]); 
                    results['Sparsity'].append(result['valid-sparsity'].mean()); 
                    results['Plausibility'].append(-1 * iforest.score_samples(result['counterfactual']).mean() if X_target.shape[0]!=0 else 0.0);                     
                    print('\t\t\t- Method: {} | Acc.: {:.4} | Val.: {:.4} | Rec.: {:.4}'.format(results['Method'][-1], results['Accuracy'][-1], results['Budget-Validity'][-1], results['Recourse'][-1]))
                    importance.append(clf.feature_importances_)


                for delta in DELTAS:
                    clf = RecourseTreeClassifier(action, max_depth=MAX_DEPTH, relabeling=True, delta=delta)
                    clf.action.alpha = alpha

                    start = time()
                    clf = clf.fit(X_tr, y_tr)
                    runtime = time() - start
                    X_target = X_ts[clf.predict(X_ts) != action.y_target]
                    result = clf.explain_action(X_target)
        
                    results['Fold'].append(k); results['Method'].append('RACT'); 
                    results['Alpha'].append(alpha); results['Budget'].append(cost_budget); results['Delta'].append(delta); 
                    results['Accuracy'].append(clf.score(X_ts, y_ts)); results['F1'].append(f1_score(y_ts, clf.predict(X_ts))); results['Time [s]'].append(runtime); 
                    results['Cost'].append(result['cost'].mean()); results['Validity'].append(result['validity'].mean()); 
                    results['Budget-Validity'].append(result['cost-validity'].mean()); results['Valid-Cost'].append(result['valid-cost'].mean()); 
                    results['Recourse'].append(1 - (~result['cost-validity']).sum() / X_ts.shape[0]); 
                    results['Sparsity'].append(result['valid-sparsity'].mean()); 
                    results['Plausibility'].append(-1 * iforest.score_samples(result['counterfactual']).mean() if X_target.shape[0]!=0 else 0.0); 
                    print('\t\t\t- Method: {} (alp.: {} | del.: {}) | Acc.: {:.4} | Val.: {:.4} | Rec.: {:.4}'.format(results['Method'][-1], alpha, delta, results['Accuracy'][-1], results['Budget-Validity'][-1], results['Recourse'][-1]))
                    importance.append(clf.feature_importances_)
       
    
    results = pd.DataFrame(results)
    results.to_csv('../res/appendix/budget/{}_tree{}.csv'.format(dataset, '_causal' if causal else ''), index=False)
    
    importance = pd.DataFrame(np.array(importance), columns=D.feature_names)
    importance = pd.concat([results[['Fold', 'Method', 'Alpha', 'Budget', 'Delta']], importance], axis=1)
    importance.to_csv('../res/appendix/budget/fi_{}_tree{}.csv'.format(dataset, '_causal' if causal else ''), index=False)

# %%
from datasets import DATASET_FULLNAMES

for dataset in DATASETS: 
    print('# {}'.format(DATASET_FULLNAMES[dataset]))
    run_holdout_tree(dataset)
# Out:
# # COMPAS
# - k = 1
# 	- budget: 0.1
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6667 | Val.: 0.2717 | Rec.: 0.6783
# 			- Method: Baseline (OAF) | Acc.: 0.6641 | Val.: 0.2531 | Rec.: 0.6518
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.5538 | Val.: 0.4295 | Rec.: 0.9449
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.5538 | Val.: 0.4295 | Rec.: 0.9449
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.5538 | Val.: 0.4295 | Rec.: 0.9449
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.5538 | Val.: 0.4295 | Rec.: 0.9449
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6667 | Val.: 0.2717 | Rec.: 0.6783
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.6556 | Val.: 0.4547 | Rec.: 0.8048
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.6556 | Val.: 0.4547 | Rec.: 0.8048
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6654 | Val.: 0.4492 | Rec.: 0.7575
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6654 | Val.: 0.4492 | Rec.: 0.7575
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6654 | Val.: 0.4492 | Rec.: 0.7575
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.6556 | Val.: 0.4547 | Rec.: 0.8048
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6556 | Val.: 0.4547 | Rec.: 0.8048
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.6654 | Val.: 0.4492 | Rec.: 0.7575
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.6654 | Val.: 0.4492 | Rec.: 0.7575
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.6654 | Val.: 0.4492 | Rec.: 0.7575
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.6518 | Val.: 0.3274 | Rec.: 0.8029
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.6518 | Val.: 0.3274 | Rec.: 0.8029
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.666 | Val.: 0.3717 | Rec.: 0.7555
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.666 | Val.: 0.3717 | Rec.: 0.7555
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.666 | Val.: 0.3717 | Rec.: 0.7555
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.5402 | Val.: 0.6667 | Rec.: 0.9987
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.6524 | Val.: 0.2559 | Rec.: 0.7756
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.6667 | Val.: 0.3165 | Rec.: 0.7283
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.6667 | Val.: 0.3165 | Rec.: 0.7283
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.6667 | Val.: 0.3165 | Rec.: 0.7283
# 	- budget: 0.2
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6667 | Val.: 0.5037 | Rec.: 0.7808
# 			- Method: Baseline (OAF) | Acc.: 0.6641 | Val.: 0.5216 | Rec.: 0.7769
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.5441 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.6569 | Val.: 0.3899 | Rec.: 0.7808
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6569 | Val.: 0.3899 | Rec.: 0.7808
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6667 | Val.: 0.5037 | Rec.: 0.7808
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6667 | Val.: 0.5037 | Rec.: 0.7808
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.6569 | Val.: 0.556 | Rec.: 0.8405
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.6667 | Val.: 0.6388 | Rec.: 0.8405
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6667 | Val.: 0.6388 | Rec.: 0.8405
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6667 | Val.: 0.6388 | Rec.: 0.8405
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6667 | Val.: 0.6388 | Rec.: 0.8405
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.6569 | Val.: 0.556 | Rec.: 0.8405
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6667 | Val.: 0.6388 | Rec.: 0.8405
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.6667 | Val.: 0.6388 | Rec.: 0.8405
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.6667 | Val.: 0.6388 | Rec.: 0.8405
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.6667 | Val.: 0.6388 | Rec.: 0.8405
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.6602 | Val.: 0.5368 | Rec.: 0.8489
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.6699 | Val.: 0.6302 | Rec.: 0.8489
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.6744 | Val.: 0.6408 | Rec.: 0.847
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.6744 | Val.: 0.6408 | Rec.: 0.847
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.6744 | Val.: 0.6408 | Rec.: 0.847
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.6595 | Val.: 0.4334 | Rec.: 0.7847
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.6595 | Val.: 0.4334 | Rec.: 0.7847
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.6693 | Val.: 0.5344 | Rec.: 0.7847
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.6693 | Val.: 0.5344 | Rec.: 0.7847
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.6693 | Val.: 0.5344 | Rec.: 0.7847
# 	- budget: 0.4
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6667 | Val.: 0.8003 | Rec.: 0.9118
# 			- Method: Baseline (OAF) | Acc.: 0.6641 | Val.: 0.8108 | Rec.: 0.9118
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.6569 | Val.: 0.7545 | Rec.: 0.9118
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.6667 | Val.: 0.8003 | Rec.: 0.9118
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6667 | Val.: 0.8003 | Rec.: 0.9118
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6667 | Val.: 0.8003 | Rec.: 0.9118
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6667 | Val.: 0.8003 | Rec.: 0.9118
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.6667 | Val.: 1.0 | Rec.: 1.0
# 	- budget: 0.5
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6667 | Val.: 0.9413 | Rec.: 0.9741
# 			- Method: Baseline (OAF) | Acc.: 0.6641 | Val.: 0.9444 | Rec.: 0.9741
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.6667 | Val.: 0.9413 | Rec.: 0.9741
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.6667 | Val.: 0.9413 | Rec.: 0.9741
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6667 | Val.: 0.9413 | Rec.: 0.9741
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6667 | Val.: 0.9413 | Rec.: 0.9741
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6667 | Val.: 0.9413 | Rec.: 0.9741
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.6667 | Val.: 0.9222 | Rec.: 0.9656
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.6667 | Val.: 0.9222 | Rec.: 0.9656
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6667 | Val.: 0.9222 | Rec.: 0.9656
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6667 | Val.: 0.9222 | Rec.: 0.9656
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6667 | Val.: 0.9222 | Rec.: 0.9656
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# - k = 2
# 	- budget: 0.1
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6686 | Val.: 0.2771 | Rec.: 0.7108
# 			- Method: Baseline (OAF) | Acc.: 0.6686 | Val.: 0.283 | Rec.: 0.7075
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.5687 | Val.: 0.531 | Rec.: 0.9656
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.5687 | Val.: 0.531 | Rec.: 0.9656
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.5687 | Val.: 0.531 | Rec.: 0.9656
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.5687 | Val.: 0.531 | Rec.: 0.9656
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6686 | Val.: 0.2771 | Rec.: 0.7108
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.5597 | Val.: 0.7556 | Rec.: 0.9929
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.6556 | Val.: 0.4427 | Rec.: 0.8139
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6667 | Val.: 0.4413 | Rec.: 0.784
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6667 | Val.: 0.4413 | Rec.: 0.784
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6667 | Val.: 0.4413 | Rec.: 0.784
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.6492 | Val.: 0.4676 | Rec.: 0.8346
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6634 | Val.: 0.4673 | Rec.: 0.8048
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.6673 | Val.: 0.459 | Rec.: 0.7905
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.6673 | Val.: 0.459 | Rec.: 0.7905
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.6673 | Val.: 0.459 | Rec.: 0.7905
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.5538 | Val.: 0.9 | Rec.: 0.9994
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.6563 | Val.: 0.3778 | Rec.: 0.8184
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.6686 | Val.: 0.3944 | Rec.: 0.7899
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.6686 | Val.: 0.3944 | Rec.: 0.7899
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.6686 | Val.: 0.3944 | Rec.: 0.7899
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.5571 | Val.: 0.9412 | Rec.: 0.9994
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.6563 | Val.: 0.3846 | Rec.: 0.8236
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.6719 | Val.: 0.3875 | Rec.: 0.7847
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.6719 | Val.: 0.3875 | Rec.: 0.7847
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.6719 | Val.: 0.3875 | Rec.: 0.7847
# 	- budget: 0.2
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6686 | Val.: 0.4263 | Rec.: 0.7704
# 			- Method: Baseline (OAF) | Acc.: 0.6686 | Val.: 0.442 | Rec.: 0.7724
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.5577 | Val.: 0.8438 | Rec.: 0.9968
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.5577 | Val.: 0.8438 | Rec.: 0.9968
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6576 | Val.: 0.3526 | Rec.: 0.775
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6686 | Val.: 0.4263 | Rec.: 0.7704
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6686 | Val.: 0.4263 | Rec.: 0.7704
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.5558 | Val.: 0.5385 | Rec.: 0.9961
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.5558 | Val.: 0.5385 | Rec.: 0.9961
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6543 | Val.: 0.2074 | Rec.: 0.7497
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6654 | Val.: 0.3046 | Rec.: 0.7438
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6706 | Val.: 0.33 | Rec.: 0.7367
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.6556 | Val.: 0.5522 | Rec.: 0.8638
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6667 | Val.: 0.6018 | Rec.: 0.858
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.6732 | Val.: 0.6224 | Rec.: 0.856
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.6732 | Val.: 0.6224 | Rec.: 0.856
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.6732 | Val.: 0.6224 | Rec.: 0.856
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.6556 | Val.: 0.5522 | Rec.: 0.8638
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.6667 | Val.: 0.6018 | Rec.: 0.858
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.6732 | Val.: 0.6224 | Rec.: 0.856
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.6732 | Val.: 0.6224 | Rec.: 0.856
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.6732 | Val.: 0.6224 | Rec.: 0.856
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.6556 | Val.: 0.5522 | Rec.: 0.8638
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.6667 | Val.: 0.6018 | Rec.: 0.858
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.6732 | Val.: 0.6224 | Rec.: 0.856
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.6732 | Val.: 0.6224 | Rec.: 0.856
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.6732 | Val.: 0.6224 | Rec.: 0.856
# 	- budget: 0.4
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6686 | Val.: 0.765 | Rec.: 0.906
# 			- Method: Baseline (OAF) | Acc.: 0.6686 | Val.: 0.7711 | Rec.: 0.9066
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.6576 | Val.: 0.7332 | Rec.: 0.9073
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.6686 | Val.: 0.765 | Rec.: 0.906
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6686 | Val.: 0.765 | Rec.: 0.906
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6686 | Val.: 0.765 | Rec.: 0.906
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6686 | Val.: 0.765 | Rec.: 0.906
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.6686 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.5791 | Val.: 0.9952 | Rec.: 0.9994
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.5791 | Val.: 0.9952 | Rec.: 0.9994
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.5791 | Val.: 0.9952 | Rec.: 0.9994
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.5791 | Val.: 0.9952 | Rec.: 0.9994
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.5791 | Val.: 0.9952 | Rec.: 0.9994
# 	- budget: 0.5
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6686 | Val.: 0.9109 | Rec.: 0.9643
# 			- Method: Baseline (OAF) | Acc.: 0.6686 | Val.: 0.9126 | Rec.: 0.9643
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.6686 | Val.: 0.9109 | Rec.: 0.9643
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.6686 | Val.: 0.9109 | Rec.: 0.9643
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6686 | Val.: 0.9109 | Rec.: 0.9643
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6686 | Val.: 0.9109 | Rec.: 0.9643
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6686 | Val.: 0.9109 | Rec.: 0.9643
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.5681 | Val.: 0.9565 | Rec.: 0.9974
# - k = 3
# 	- budget: 0.1
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6738 | Val.: 0.1923 | Rec.: 0.6732
# 			- Method: Baseline (OAF) | Acc.: 0.677 | Val.: 0.1928 | Rec.: 0.6634
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.5558 | Val.: 0.6429 | Rec.: 0.9935
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.5558 | Val.: 0.6429 | Rec.: 0.9935
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.5558 | Val.: 0.6429 | Rec.: 0.9935
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6582 | Val.: 0.1382 | Rec.: 0.6926
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6582 | Val.: 0.1382 | Rec.: 0.6926
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.5642 | Val.: 0.7872 | Rec.: 0.9935
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.5642 | Val.: 0.7872 | Rec.: 0.9935
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.5642 | Val.: 0.7872 | Rec.: 0.9935
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6641 | Val.: 0.1262 | Rec.: 0.7082
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6796 | Val.: 0.1868 | Rec.: 0.6894
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.5577 | Val.: 0.6667 | Rec.: 0.9981
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6569 | Val.: 0.286 | Rec.: 0.7815
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.6725 | Val.: 0.3315 | Rec.: 0.7633
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.6803 | Val.: 0.3265 | Rec.: 0.7458
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.6803 | Val.: 0.3265 | Rec.: 0.7458
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.5577 | Val.: 0.7647 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.6518 | Val.: 0.2983 | Rec.: 0.7834
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.668 | Val.: 0.343 | Rec.: 0.7652
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.668 | Val.: 0.343 | Rec.: 0.7652
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.668 | Val.: 0.343 | Rec.: 0.7652
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.5577 | Val.: 0.9091 | Rec.: 0.9994
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.6472 | Val.: 0.3326 | Rec.: 0.8022
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.666 | Val.: 0.3595 | Rec.: 0.7724
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.666 | Val.: 0.3595 | Rec.: 0.7724
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.666 | Val.: 0.3595 | Rec.: 0.7724
# 	- budget: 0.2
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6738 | Val.: 0.3317 | Rec.: 0.7296
# 			- Method: Baseline (OAF) | Acc.: 0.677 | Val.: 0.3453 | Rec.: 0.727
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.5571 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.5571 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6582 | Val.: 0.2564 | Rec.: 0.7348
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6582 | Val.: 0.2564 | Rec.: 0.7348
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6738 | Val.: 0.3317 | Rec.: 0.7296
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.5577 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.5577 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6576 | Val.: 0.2369 | Rec.: 0.7639
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6732 | Val.: 0.3321 | Rec.: 0.7613
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6732 | Val.: 0.3321 | Rec.: 0.7613
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.6569 | Val.: 0.5678 | Rec.: 0.8677
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6725 | Val.: 0.6209 | Rec.: 0.8658
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.679 | Val.: 0.631 | Rec.: 0.8593
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.679 | Val.: 0.631 | Rec.: 0.8593
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.679 | Val.: 0.631 | Rec.: 0.8593
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.6608 | Val.: 0.6304 | Rec.: 0.8898
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.6608 | Val.: 0.6304 | Rec.: 0.8898
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.679 | Val.: 0.6519 | Rec.: 0.8781
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.679 | Val.: 0.6519 | Rec.: 0.8781
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.679 | Val.: 0.6519 | Rec.: 0.8781
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.5817 | Val.: 0.9783 | Rec.: 0.9981
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.5817 | Val.: 0.9783 | Rec.: 0.9981
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.5817 | Val.: 0.9783 | Rec.: 0.9981
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.5817 | Val.: 0.9783 | Rec.: 0.9981
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.6751 | Val.: 0.223 | Rec.: 0.7017
# 	- budget: 0.4
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6738 | Val.: 0.7228 | Rec.: 0.8878
# 			- Method: Baseline (OAF) | Acc.: 0.677 | Val.: 0.7061 | Rec.: 0.8774
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.6582 | Val.: 0.6982 | Rec.: 0.8923
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.6582 | Val.: 0.6982 | Rec.: 0.8923
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6738 | Val.: 0.7228 | Rec.: 0.8878
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6738 | Val.: 0.7228 | Rec.: 0.8878
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6738 | Val.: 0.7228 | Rec.: 0.8878
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.6738 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.6738 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6738 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6738 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6738 | Val.: 0.9935 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.6738 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6738 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.6738 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.6738 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.6738 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.6738 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.6738 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.6738 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.6738 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.6738 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.5811 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.5811 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.5811 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.5811 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.6744 | Val.: 0.7208 | Rec.: 0.893
# 	- budget: 0.5
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6738 | Val.: 0.8878 | Rec.: 0.9546
# 			- Method: Baseline (OAF) | Acc.: 0.677 | Val.: 0.8616 | Rec.: 0.9423
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.6738 | Val.: 0.8878 | Rec.: 0.9546
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.6738 | Val.: 0.8878 | Rec.: 0.9546
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6738 | Val.: 0.8878 | Rec.: 0.9546
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6738 | Val.: 0.8878 | Rec.: 0.9546
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6738 | Val.: 0.8878 | Rec.: 0.9546
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# - k = 4
# 	- budget: 0.1
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6946 | Val.: 0.2688 | Rec.: 0.6719
# 			- Method: Baseline (OAF) | Acc.: 0.69 | Val.: 0.2685 | Rec.: 0.6608
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.5512 | Val.: 0.907 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.5512 | Val.: 0.907 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.668 | Val.: 0.2613 | Rec.: 0.7361
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.668 | Val.: 0.2613 | Rec.: 0.7361
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6946 | Val.: 0.2688 | Rec.: 0.6719
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.5473 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.6634 | Val.: 0.4327 | Rec.: 0.8087
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.69 | Val.: 0.4093 | Rec.: 0.7445
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6913 | Val.: 0.3991 | Rec.: 0.7393
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6913 | Val.: 0.3991 | Rec.: 0.7393
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.6511 | Val.: 0.3813 | Rec.: 0.8327
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6511 | Val.: 0.3813 | Rec.: 0.8327
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.6822 | Val.: 0.38 | Rec.: 0.7672
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.6822 | Val.: 0.38 | Rec.: 0.7672
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.6822 | Val.: 0.38 | Rec.: 0.7672
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.6505 | Val.: 0.3816 | Rec.: 0.834
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.6505 | Val.: 0.3816 | Rec.: 0.834
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.6829 | Val.: 0.3793 | Rec.: 0.7665
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.6829 | Val.: 0.3793 | Rec.: 0.7665
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.6829 | Val.: 0.3793 | Rec.: 0.7665
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.644 | Val.: 0.3625 | Rec.: 0.8346
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.6505 | Val.: 0.4083 | Rec.: 0.8327
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.6829 | Val.: 0.4261 | Rec.: 0.7886
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.6816 | Val.: 0.4193 | Rec.: 0.7853
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.6816 | Val.: 0.4193 | Rec.: 0.7853
# 	- budget: 0.2
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6946 | Val.: 0.4884 | Rec.: 0.7704
# 			- Method: Baseline (OAF) | Acc.: 0.69 | Val.: 0.5119 | Rec.: 0.7737
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.5512 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.668 | Val.: 0.3739 | Rec.: 0.7763
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.668 | Val.: 0.3739 | Rec.: 0.7763
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6946 | Val.: 0.4884 | Rec.: 0.7704
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6946 | Val.: 0.4884 | Rec.: 0.7704
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.5532 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6706 | Val.: 0.2614 | Rec.: 0.738
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6706 | Val.: 0.2614 | Rec.: 0.738
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6971 | Val.: 0.407 | Rec.: 0.7354
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.6699 | Val.: 0.5864 | Rec.: 0.8541
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6965 | Val.: 0.6657 | Rec.: 0.8515
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.6965 | Val.: 0.6657 | Rec.: 0.8515
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.6965 | Val.: 0.6657 | Rec.: 0.8515
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.6965 | Val.: 0.6657 | Rec.: 0.8515
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.6641 | Val.: 0.6844 | Rec.: 0.8962
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.6958 | Val.: 0.7251 | Rec.: 0.882
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.6958 | Val.: 0.7251 | Rec.: 0.882
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.6958 | Val.: 0.7251 | Rec.: 0.882
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.6958 | Val.: 0.7251 | Rec.: 0.882
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.6641 | Val.: 0.6844 | Rec.: 0.8962
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.6958 | Val.: 0.7251 | Rec.: 0.882
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.6958 | Val.: 0.7251 | Rec.: 0.882
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.6958 | Val.: 0.7251 | Rec.: 0.882
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.6958 | Val.: 0.7251 | Rec.: 0.882
# 	- budget: 0.4
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6946 | Val.: 0.8092 | Rec.: 0.9144
# 			- Method: Baseline (OAF) | Acc.: 0.69 | Val.: 0.8224 | Rec.: 0.9176
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.668 | Val.: 0.7695 | Rec.: 0.9176
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.6946 | Val.: 0.8092 | Rec.: 0.9144
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6946 | Val.: 0.8092 | Rec.: 0.9144
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6946 | Val.: 0.8092 | Rec.: 0.9144
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6946 | Val.: 0.8092 | Rec.: 0.9144
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.6952 | Val.: 0.9971 | Rec.: 0.9987
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.6952 | Val.: 0.9971 | Rec.: 0.9987
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6952 | Val.: 0.9971 | Rec.: 0.9987
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6952 | Val.: 0.9971 | Rec.: 0.9987
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6952 | Val.: 0.9971 | Rec.: 0.9987
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.6939 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6939 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.6939 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.6939 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.6939 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.5869 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.5869 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.5869 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.5869 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.5869 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.5869 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.5869 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.5869 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.5869 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.5869 | Val.: 1.0 | Rec.: 1.0
# 	- budget: 0.5
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6946 | Val.: 0.9277 | Rec.: 0.9676
# 			- Method: Baseline (OAF) | Acc.: 0.69 | Val.: 0.9399 | Rec.: 0.9721
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.6946 | Val.: 0.9277 | Rec.: 0.9676
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.6946 | Val.: 0.9277 | Rec.: 0.9676
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6946 | Val.: 0.9277 | Rec.: 0.9676
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6946 | Val.: 0.9277 | Rec.: 0.9676
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6946 | Val.: 0.9277 | Rec.: 0.9676
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.6952 | Val.: 0.912 | Rec.: 0.9604
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.6952 | Val.: 0.912 | Rec.: 0.9604
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6952 | Val.: 0.912 | Rec.: 0.9604
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6952 | Val.: 0.912 | Rec.: 0.9604
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6952 | Val.: 0.912 | Rec.: 0.9604
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.572 | Val.: 1.0 | Rec.: 1.0
# - k = 5
# 	- budget: 0.1
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6641 | Val.: 0.183 | Rec.: 0.6323
# 			- Method: Baseline (OAF) | Acc.: 0.6628 | Val.: 0.1839 | Rec.: 0.6316
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.559 | Val.: 0.7273 | Rec.: 0.9961
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.559 | Val.: 0.7273 | Rec.: 0.9961
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.559 | Val.: 0.7273 | Rec.: 0.9961
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6498 | Val.: 0.1123 | Rec.: 0.6719
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6641 | Val.: 0.183 | Rec.: 0.6323
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.5603 | Val.: 0.8889 | Rec.: 0.9987
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.5603 | Val.: 0.8889 | Rec.: 0.9987
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6492 | Val.: 0.2882 | Rec.: 0.7374
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6634 | Val.: 0.3276 | Rec.: 0.6978
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6634 | Val.: 0.3276 | Rec.: 0.6978
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.6336 | Val.: 0.3545 | Rec.: 0.8087
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6511 | Val.: 0.4061 | Rec.: 0.7743
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.6524 | Val.: 0.385 | Rec.: 0.7607
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.6524 | Val.: 0.385 | Rec.: 0.7607
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.6524 | Val.: 0.385 | Rec.: 0.7607
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.5597 | Val.: 0.8889 | Rec.: 0.9994
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.6349 | Val.: 0.2675 | Rec.: 0.7763
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.6537 | Val.: 0.3176 | Rec.: 0.7283
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.6537 | Val.: 0.3176 | Rec.: 0.7283
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.6537 | Val.: 0.3176 | Rec.: 0.7283
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.5934 | Val.: 0.7313 | Rec.: 0.965
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.5934 | Val.: 0.7313 | Rec.: 0.965
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.5934 | Val.: 0.7313 | Rec.: 0.965
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.6602 | Val.: 0.1736 | Rec.: 0.6913
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.6602 | Val.: 0.1736 | Rec.: 0.6913
# 	- budget: 0.2
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6641 | Val.: 0.3501 | Rec.: 0.7075
# 			- Method: Baseline (OAF) | Acc.: 0.6628 | Val.: 0.3491 | Rec.: 0.7062
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.559 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.559 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6498 | Val.: 0.2228 | Rec.: 0.7127
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6498 | Val.: 0.2228 | Rec.: 0.7127
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6641 | Val.: 0.3501 | Rec.: 0.7075
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.6492 | Val.: 0.5378 | Rec.: 0.8294
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.6634 | Val.: 0.6089 | Rec.: 0.8243
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6634 | Val.: 0.6089 | Rec.: 0.8243
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6634 | Val.: 0.6089 | Rec.: 0.8243
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6634 | Val.: 0.6089 | Rec.: 0.8243
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.6479 | Val.: 0.5348 | Rec.: 0.8482
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6621 | Val.: 0.6093 | Rec.: 0.8411
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.668 | Val.: 0.6288 | Rec.: 0.8411
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.668 | Val.: 0.6288 | Rec.: 0.8411
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.668 | Val.: 0.6288 | Rec.: 0.8411
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.5875 | Val.: 0.9356 | Rec.: 0.9916
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.5875 | Val.: 0.9356 | Rec.: 0.9916
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.5875 | Val.: 0.9356 | Rec.: 0.9916
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.5875 | Val.: 0.9356 | Rec.: 0.9916
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.6628 | Val.: 0.2928 | Rec.: 0.6946
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.6025 | Val.: 0.9728 | Rec.: 0.9955
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.6025 | Val.: 0.9728 | Rec.: 0.9955
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.6025 | Val.: 0.9728 | Rec.: 0.9955
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.6025 | Val.: 0.9728 | Rec.: 0.9955
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.6693 | Val.: 0.3908 | Rec.: 0.7503
# 	- budget: 0.4
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6641 | Val.: 0.7003 | Rec.: 0.8651
# 			- Method: Baseline (OAF) | Acc.: 0.6628 | Val.: 0.7011 | Rec.: 0.8651
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.6498 | Val.: 0.6491 | Rec.: 0.8703
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.6498 | Val.: 0.6491 | Rec.: 0.8703
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6641 | Val.: 0.7003 | Rec.: 0.8651
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6641 | Val.: 0.7003 | Rec.: 0.8651
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6641 | Val.: 0.7003 | Rec.: 0.8651
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.6634 | Val.: 0.9913 | Rec.: 0.9961
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.6634 | Val.: 0.9913 | Rec.: 0.9961
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6634 | Val.: 0.9913 | Rec.: 0.9961
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6634 | Val.: 0.9913 | Rec.: 0.9961
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6634 | Val.: 0.9913 | Rec.: 0.9961
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.6641 | Val.: 0.9942 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6641 | Val.: 0.9942 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.6641 | Val.: 0.9942 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.6641 | Val.: 0.9942 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.6641 | Val.: 0.9942 | Rec.: 0.9974
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.5752 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.5752 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.5752 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.6511 | Val.: 0.7201 | Rec.: 0.8878
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.6615 | Val.: 0.7251 | Rec.: 0.882
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.5759 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.5759 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.5759 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.6518 | Val.: 0.7593 | Rec.: 0.904
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.6628 | Val.: 0.7705 | Rec.: 0.9021
# 	- budget: 0.5
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6641 | Val.: 0.8501 | Rec.: 0.9326
# 			- Method: Baseline (OAF) | Acc.: 0.6628 | Val.: 0.8506 | Rec.: 0.9326
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.6641 | Val.: 0.8501 | Rec.: 0.9326
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.6641 | Val.: 0.8501 | Rec.: 0.9326
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6641 | Val.: 0.8501 | Rec.: 0.9326
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6641 | Val.: 0.8501 | Rec.: 0.9326
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6641 | Val.: 0.8501 | Rec.: 0.9326
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.5577 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.5577 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.5577 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.5577 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6479 | Val.: 0.5214 | Rec.: 0.8184
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.5726 | Val.: 1.0 | Rec.: 1.0
# - k = 6
# 	- budget: 0.1
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.6537 | Val.: 0.2514 | Rec.: 0.6602
# 			- Method: Baseline (OAF) | Acc.: 0.6511 | Val.: 0.252 | Rec.: 0.644
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.5415 | Val.: 0.5405 | Rec.: 0.989
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.5415 | Val.: 0.5405 | Rec.: 0.989
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.6316 | Val.: 0.235 | Rec.: 0.7192
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.6316 | Val.: 0.235 | Rec.: 0.7192
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.6537 | Val.: 0.2514 | Rec.: 0.6602
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.5383 | Val.: 0.4091 | Rec.: 0.9916
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.6271 | Val.: 0.4545 | Rec.: 0.8016
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.6271 | Val.: 0.4545 | Rec.: 0.8016
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.6537 | Val.: 0.4302 | Rec.: 0.7406
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.6537 | Val.: 0.4302 | Rec.: 0.7406
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.5415 | Val.: 0.5556 | Rec.: 0.9922
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.6323 | Val.: 0.4821 | Rec.: 0.8029
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.6511 | Val.: 0.457 | Rec.: 0.7626
# ...
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.8085 | Val.: 0.5136 | Rec.: 0.9475
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.8085 | Val.: 0.5136 | Rec.: 0.9475
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.8085 | Val.: 0.5136 | Rec.: 0.9475
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.8085 | Val.: 0.5136 | Rec.: 0.9475
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.8085 | Val.: 0.5136 | Rec.: 0.9475
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.8083 | Val.: 0.3709 | Rec.: 0.9292
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.8083 | Val.: 0.3709 | Rec.: 0.9292
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.8083 | Val.: 0.3709 | Rec.: 0.9292
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.8083 | Val.: 0.3709 | Rec.: 0.9292
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.8083 | Val.: 0.3709 | Rec.: 0.9292
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.8065 | Val.: 0.3802 | Rec.: 0.9459
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.8065 | Val.: 0.3802 | Rec.: 0.9459
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.8065 | Val.: 0.3802 | Rec.: 0.9459
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.8065 | Val.: 0.3802 | Rec.: 0.9459
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.8065 | Val.: 0.3802 | Rec.: 0.9459
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.8055 | Val.: 0.413 | Rec.: 0.9555
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.8055 | Val.: 0.413 | Rec.: 0.9555
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.8055 | Val.: 0.413 | Rec.: 0.9555
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.8055 | Val.: 0.413 | Rec.: 0.9555
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.8055 | Val.: 0.413 | Rec.: 0.9555
# 	- budget: 0.4
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.808 | Val.: 0.7593 | Rec.: 0.9741
# 			- Method: Baseline (OAF) | Acc.: 0.7773 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.808 | Val.: 0.7593 | Rec.: 0.9741
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.808 | Val.: 0.7593 | Rec.: 0.9741
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.808 | Val.: 0.7593 | Rec.: 0.9741
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.808 | Val.: 0.7593 | Rec.: 0.9741
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.808 | Val.: 0.7593 | Rec.: 0.9741
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.8083 | Val.: 0.4171 | Rec.: 0.9344
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.8083 | Val.: 0.4171 | Rec.: 0.9344
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.8083 | Val.: 0.4171 | Rec.: 0.9344
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.8083 | Val.: 0.4171 | Rec.: 0.9344
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.8083 | Val.: 0.4171 | Rec.: 0.9344
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.8095 | Val.: 0.9176 | Rec.: 0.9909
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.8095 | Val.: 0.9176 | Rec.: 0.9909
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.8095 | Val.: 0.9176 | Rec.: 0.9909
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.8095 | Val.: 0.9176 | Rec.: 0.9909
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.8095 | Val.: 0.9176 | Rec.: 0.9909
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.806 | Val.: 0.813 | Rec.: 0.9839
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.806 | Val.: 0.813 | Rec.: 0.9839
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.806 | Val.: 0.813 | Rec.: 0.9839
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.806 | Val.: 0.813 | Rec.: 0.9839
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.806 | Val.: 0.813 | Rec.: 0.9839
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.806 | Val.: 0.8554 | Rec.: 0.9888
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.806 | Val.: 0.8554 | Rec.: 0.9888
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.806 | Val.: 0.8554 | Rec.: 0.9888
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.806 | Val.: 0.8554 | Rec.: 0.9888
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.806 | Val.: 0.8554 | Rec.: 0.9888
# 	- budget: 0.5
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.808 | Val.: 0.8586 | Rec.: 0.9848
# 			- Method: Baseline (OAF) | Acc.: 0.7773 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.808 | Val.: 0.8586 | Rec.: 0.9848
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.808 | Val.: 0.8586 | Rec.: 0.9848
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.808 | Val.: 0.8586 | Rec.: 0.9848
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.808 | Val.: 0.8586 | Rec.: 0.9848
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.808 | Val.: 0.8586 | Rec.: 0.9848
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.8084 | Val.: 0.8538 | Rec.: 0.9843
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.8084 | Val.: 0.8538 | Rec.: 0.9843
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.8084 | Val.: 0.8538 | Rec.: 0.9843
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.8084 | Val.: 0.8538 | Rec.: 0.9843
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.8084 | Val.: 0.8538 | Rec.: 0.9843
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.8084 | Val.: 0.8538 | Rec.: 0.9843
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.8084 | Val.: 0.8538 | Rec.: 0.9843
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.8084 | Val.: 0.8538 | Rec.: 0.9843
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.8084 | Val.: 0.8538 | Rec.: 0.9843
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.8084 | Val.: 0.8538 | Rec.: 0.9843
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.806 | Val.: 0.8792 | Rec.: 0.9899
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.806 | Val.: 0.8792 | Rec.: 0.9899
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.806 | Val.: 0.8792 | Rec.: 0.9899
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.806 | Val.: 0.8792 | Rec.: 0.9899
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.806 | Val.: 0.8792 | Rec.: 0.9899
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.8057 | Val.: 0.8645 | Rec.: 0.9899
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.8057 | Val.: 0.8645 | Rec.: 0.9899
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.8057 | Val.: 0.8645 | Rec.: 0.9899
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.8057 | Val.: 0.8645 | Rec.: 0.9899
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.8057 | Val.: 0.8645 | Rec.: 0.9899
# - k = 30
# 	- budget: 0.1
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.8028 | Val.: 0.1594 | Rec.: 0.9072
# 			- Method: Baseline (OAF) | Acc.: 0.7753 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.8028 | Val.: 0.1594 | Rec.: 0.9072
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.8028 | Val.: 0.1594 | Rec.: 0.9072
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.8028 | Val.: 0.1594 | Rec.: 0.9072
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.8028 | Val.: 0.1594 | Rec.: 0.9072
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.8028 | Val.: 0.1594 | Rec.: 0.9072
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.8035 | Val.: 0.1361 | Rec.: 0.9027
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.8035 | Val.: 0.1361 | Rec.: 0.9027
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.8035 | Val.: 0.1361 | Rec.: 0.9027
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.8035 | Val.: 0.1361 | Rec.: 0.9027
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.8035 | Val.: 0.1361 | Rec.: 0.9027
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.8029 | Val.: 0.1356 | Rec.: 0.9065
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.8029 | Val.: 0.1356 | Rec.: 0.9065
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.8029 | Val.: 0.1356 | Rec.: 0.9065
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.8029 | Val.: 0.1356 | Rec.: 0.9065
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.8029 | Val.: 0.1356 | Rec.: 0.9065
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.7988 | Val.: 0.2208 | Rec.: 0.9341
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.7988 | Val.: 0.2208 | Rec.: 0.9341
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.7988 | Val.: 0.2208 | Rec.: 0.9341
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.7988 | Val.: 0.2208 | Rec.: 0.9341
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.7988 | Val.: 0.2208 | Rec.: 0.9341
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.7988 | Val.: 0.2208 | Rec.: 0.9341
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.7988 | Val.: 0.2208 | Rec.: 0.9341
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.7988 | Val.: 0.2208 | Rec.: 0.9341
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.7988 | Val.: 0.2208 | Rec.: 0.9341
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.7988 | Val.: 0.2208 | Rec.: 0.9341
# 	- budget: 0.2
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.8028 | Val.: 0.4879 | Rec.: 0.9435
# 			- Method: Baseline (OAF) | Acc.: 0.7753 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.8028 | Val.: 0.4879 | Rec.: 0.9435
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.8028 | Val.: 0.4879 | Rec.: 0.9435
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.8028 | Val.: 0.4879 | Rec.: 0.9435
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.8028 | Val.: 0.4879 | Rec.: 0.9435
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.8028 | Val.: 0.4879 | Rec.: 0.9435
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.8032 | Val.: 0.4757 | Rec.: 0.9411
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.8032 | Val.: 0.4757 | Rec.: 0.9411
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.8032 | Val.: 0.4757 | Rec.: 0.9411
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.8032 | Val.: 0.4757 | Rec.: 0.9411
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.8032 | Val.: 0.4757 | Rec.: 0.9411
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.8024 | Val.: 0.4656 | Rec.: 0.9389
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.8024 | Val.: 0.4656 | Rec.: 0.9389
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.8024 | Val.: 0.4656 | Rec.: 0.9389
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.8024 | Val.: 0.4656 | Rec.: 0.9389
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.8024 | Val.: 0.4656 | Rec.: 0.9389
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.7985 | Val.: 0.4984 | Rec.: 0.9569
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.7985 | Val.: 0.4984 | Rec.: 0.9569
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.7985 | Val.: 0.4984 | Rec.: 0.9569
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.7985 | Val.: 0.4984 | Rec.: 0.9569
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.7985 | Val.: 0.4984 | Rec.: 0.9569
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.7985 | Val.: 0.4984 | Rec.: 0.9569
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.7985 | Val.: 0.4984 | Rec.: 0.9569
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.7985 | Val.: 0.4984 | Rec.: 0.9569
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.7985 | Val.: 0.4984 | Rec.: 0.9569
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.7985 | Val.: 0.4984 | Rec.: 0.9569
# 	- budget: 0.4
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.8028 | Val.: 0.7693 | Rec.: 0.9745
# 			- Method: Baseline (OAF) | Acc.: 0.7753 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.8028 | Val.: 0.7693 | Rec.: 0.9745
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.8028 | Val.: 0.7693 | Rec.: 0.9745
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.8028 | Val.: 0.7693 | Rec.: 0.9745
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.8028 | Val.: 0.7693 | Rec.: 0.9745
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.8028 | Val.: 0.7693 | Rec.: 0.9745
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.8029 | Val.: 0.9419 | Rec.: 0.9935
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.8029 | Val.: 0.9419 | Rec.: 0.9935
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.8029 | Val.: 0.9419 | Rec.: 0.9935
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.8029 | Val.: 0.9419 | Rec.: 0.9935
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.8029 | Val.: 0.9419 | Rec.: 0.9935
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.8044 | Val.: 0.8095 | Rec.: 0.9787
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.8044 | Val.: 0.8095 | Rec.: 0.9787
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.8044 | Val.: 0.8095 | Rec.: 0.9787
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.8044 | Val.: 0.8095 | Rec.: 0.9787
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.8044 | Val.: 0.8095 | Rec.: 0.9787
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.7999 | Val.: 0.9795 | Rec.: 0.9983
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.7999 | Val.: 0.9795 | Rec.: 0.9983
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.7999 | Val.: 0.9795 | Rec.: 0.9983
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.7999 | Val.: 0.9795 | Rec.: 0.9983
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.7999 | Val.: 0.9795 | Rec.: 0.9983
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.7999 | Val.: 0.9795 | Rec.: 0.9983
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.7999 | Val.: 0.9795 | Rec.: 0.9983
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.7999 | Val.: 0.9795 | Rec.: 0.9983
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.7999 | Val.: 0.9795 | Rec.: 0.9983
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.7999 | Val.: 0.9795 | Rec.: 0.9983
# 	- budget: 0.5
# 			- Method: Baseline (alp.: 0.0) | Acc.: 0.8028 | Val.: 0.8478 | Rec.: 0.9832
# 			- Method: Baseline (OAF) | Acc.: 0.7753 | Val.: 1.0 | Rec.: 1.0
# 			- Method: RACT (alp.: 0.0 | del.: 0.2) | Acc.: 0.8028 | Val.: 0.8478 | Rec.: 0.9832
# 			- Method: RACT (alp.: 0.0 | del.: 0.25) | Acc.: 0.8028 | Val.: 0.8478 | Rec.: 0.9832
# 			- Method: RACT (alp.: 0.0 | del.: 0.3) | Acc.: 0.8028 | Val.: 0.8478 | Rec.: 0.9832
# 			- Method: RACT (alp.: 0.0 | del.: 0.35) | Acc.: 0.8028 | Val.: 0.8478 | Rec.: 0.9832
# 			- Method: RACT (alp.: 0.0 | del.: 0.4) | Acc.: 0.8028 | Val.: 0.8478 | Rec.: 0.9832
# 			- Method: RACT (alp.: 0.025 | del.: 0.2) | Acc.: 0.8027 | Val.: 0.8851 | Rec.: 0.9877
# 			- Method: RACT (alp.: 0.025 | del.: 0.25) | Acc.: 0.8027 | Val.: 0.8851 | Rec.: 0.9877
# 			- Method: RACT (alp.: 0.025 | del.: 0.3) | Acc.: 0.8027 | Val.: 0.8851 | Rec.: 0.9877
# 			- Method: RACT (alp.: 0.025 | del.: 0.35) | Acc.: 0.8027 | Val.: 0.8851 | Rec.: 0.9877
# 			- Method: RACT (alp.: 0.025 | del.: 0.4) | Acc.: 0.8027 | Val.: 0.8851 | Rec.: 0.9877
# 			- Method: RACT (alp.: 0.05 | del.: 0.2) | Acc.: 0.8027 | Val.: 0.8851 | Rec.: 0.9877
# 			- Method: RACT (alp.: 0.05 | del.: 0.25) | Acc.: 0.8027 | Val.: 0.8851 | Rec.: 0.9877
# 			- Method: RACT (alp.: 0.05 | del.: 0.3) | Acc.: 0.8027 | Val.: 0.8851 | Rec.: 0.9877
# 			- Method: RACT (alp.: 0.05 | del.: 0.35) | Acc.: 0.8027 | Val.: 0.8851 | Rec.: 0.9877
# 			- Method: RACT (alp.: 0.05 | del.: 0.4) | Acc.: 0.8027 | Val.: 0.8851 | Rec.: 0.9877
# 			- Method: RACT (alp.: 0.075 | del.: 0.2) | Acc.: 0.798 | Val.: 0.8955 | Rec.: 0.9913
# 			- Method: RACT (alp.: 0.075 | del.: 0.25) | Acc.: 0.798 | Val.: 0.8955 | Rec.: 0.9913
# 			- Method: RACT (alp.: 0.075 | del.: 0.3) | Acc.: 0.798 | Val.: 0.8955 | Rec.: 0.9913
# 			- Method: RACT (alp.: 0.075 | del.: 0.35) | Acc.: 0.798 | Val.: 0.8955 | Rec.: 0.9913
# 			- Method: RACT (alp.: 0.075 | del.: 0.4) | Acc.: 0.798 | Val.: 0.8955 | Rec.: 0.9913
# 			- Method: RACT (alp.: 0.1 | del.: 0.2) | Acc.: 0.798 | Val.: 0.8955 | Rec.: 0.9913
# 			- Method: RACT (alp.: 0.1 | del.: 0.25) | Acc.: 0.798 | Val.: 0.8955 | Rec.: 0.9913
# 			- Method: RACT (alp.: 0.1 | del.: 0.3) | Acc.: 0.798 | Val.: 0.8955 | Rec.: 0.9913
# 			- Method: RACT (alp.: 0.1 | del.: 0.35) | Acc.: 0.798 | Val.: 0.8955 | Rec.: 0.9913
# 			- Method: RACT (alp.: 0.1 | del.: 0.4) | Acc.: 0.798 | Val.: 0.8955 | Rec.: 0.9913
